# %%
# Follow instructions here:
# https://www.kaggle.com/c/siim-acr-pneumothorax-segmentation/overview/siim-cloud-healthcare-api-tutorial

# 1. Install google cloud package
# 2. join the competition group
# 3. Authenticate through bash using:
# gcloud auth application-default login

# after that the script below should work
# Or they are also available online but might be outdated:
# https://drive.google.com/drive/folders/1vNLfdw-X3Z2-n1j-KPGLbPQ5ciDydsiX?usp=drive_open

# %%
# !pip install google-auth
# Out:
# Collecting google-auth
#   Downloading https://files.pythonhosted.org/packages/c5/9b/ed0516cc1f7609fb0217e3057ff4f0f9f3e3ce79a369c6af4a6c5ca25664/google_auth-1.6.3-py2.py3-none-any.whl (73kB)
#     100% |████████████████████████████████| 81kB 3.7MB/s ta 0:00:01
# Collecting pyasn1-modules>=0.2.1 (from google-auth)
#   Downloading https://files.pythonhosted.org/packages/91/f0/b03e00ce9fddf4827c42df1c3ce10c74eadebfb706231e8d6d1c356a4062/pyasn1_modules-0.2.5-py2.py3-none-any.whl (74kB)
#     100% |████████████████████████████████| 81kB 8.7MB/s eta 0:00:01    96% |██████████████████████████████▊ | 71kB 14.4MB/s eta 0:00:01
# Collecting rsa>=3.1.4 (from google-auth)
#   Downloading https://files.pythonhosted.org/packages/02/e5/38518af393f7c214357079ce67a317307936896e961e35450b70fad2a9cf/rsa-4.0-py2.py3-none-any.whl
# Requirement already satisfied: six>=1.9.0 in /home/daniil/anaconda3/lib/python3.7/site-packages (from google-auth) (1.10.0)
# Collecting cachetools>=2.0.0 (from google-auth)
#   Downloading https://files.pythonhosted.org/packages/2f/a6/30b0a0bef12283e83e58c1d6e7b5aabc7acfc4110df81a4471655d33e704/cachetools-3.1.1-py2.py3-none-any.whl
# Collecting pyasn1<0.5.0,>=0.4.1 (from pyasn1-modules>=0.2.1->google-auth)
#   Downloading https://files.pythonhosted.org/packages/7b/7c/c9386b82a25115cccf1903441bba3cbadcfae7b678a20167347fa8ded34c/pyasn1-0.4.5-py2.py3-none-any.whl (73kB)
#     100% |████████████████████████████████| 81kB 18.9MB/s ta 0:00:01
# Installing collected packages: pyasn1, pyasn1-modules, rsa, cachetools, google-auth
# Successfully installed cachetools-3.1.1 google-auth-1.6.3 pyasn1-0.4.5 pyasn1-modules-0.2.5 rsa-4.0

# %%
# !pip install retrying
# Out:
# Requirement already satisfied: retrying in /home/daniil/anaconda3/lib/python3.7/site-packages (1.3.3)
# Requirement already satisfied: six>=1.7.0 in /home/daniil/anaconda3/lib/python3.7/site-packages (from retrying) (1.10.0)

# %%
"""Script to download all instances in a DICOM Store."""
import os
import posixpath
from concurrent import futures
from retrying import retry
import google.auth
from google.auth.transport.requests import AuthorizedSession

# URL of CHC API
CHC_API_URL = 'https://healthcare.googleapis.com/v1beta1'
PROJECT_ID = 'kaggle-siim-healthcare'
REGION = 'us-central1'
DATASET_ID = 'siim-pneumothorax'
TRAIN_DICOM_STORE_ID = 'dicom-images-train'
TEST_DICOM_STORE_ID = 'dicom-images-test'


@retry(wait_exponential_multiplier=1000, wait_exponential_max=10000)
def download_instance(dicom_web_url, dicom_store_id, study_uid, series_uid,
                      instance_uid, credentials):
    """Downloads a DICOM instance and saves it under the current folder."""
    instance_url = posixpath.join(dicom_web_url, 'studies', study_uid, 'series',
                                  series_uid, 'instances', instance_uid)
    authed_session = AuthorizedSession(credentials)
    response = authed_session.get(
        instance_url, headers={'Accept': 'application/dicom; transfer-syntax=*'})
    file_path = posixpath.join(dicom_store_id, study_uid, series_uid,
                               instance_uid)
    filename = '%s.dcm' % file_path
    if not os.path.exists(filename):
        os.makedirs(os.path.dirname(filename))
    with open(filename, 'wb') as f:
        f.write(response.content)


def download_all_instances(dicom_store_id, credentials):
    """Downloads all DICOM instances in the specified DICOM store."""
    # Get a list of all instances.
    dicom_web_url = posixpath.join(CHC_API_URL, 'projects', PROJECT_ID,
                                   'locations', REGION, 'datasets', DATASET_ID,
                                   'dicomStores', dicom_store_id, 'dicomWeb')
    qido_url = posixpath.join(dicom_web_url, 'instances')
    authed_session = AuthorizedSession(credentials)
    response = authed_session.get(qido_url, params={'limit': '15000'})
    if response.status_code != 200:
        print(response.text)
        return
    content = response.json()
    # DICOM Tag numbers
    study_instance_uid_tag = '0020000D'
    series_instance_uid_tag = '0020000E'
    sop_instance_uid_tag = '00080018'
    value_key = 'Value'
    with futures.ThreadPoolExecutor() as executor:
        future_to_study_uid = {}
        for instance in content:
            study_uid = instance[study_instance_uid_tag][value_key][0]
            series_uid = instance[series_instance_uid_tag][value_key][0]
            instance_uid = instance[sop_instance_uid_tag][value_key][0]
            future = executor.submit(download_instance, dicom_web_url, dicom_store_id,
                                     study_uid, series_uid, instance_uid, credentials)
            future_to_study_uid[future] = study_uid
        processed_count = 0
        for future in futures.as_completed(future_to_study_uid):
            try:
                future.result()
                processed_count += 1
                if not processed_count % 100 or processed_count == len(content):
                    print('Processed instance %d out of %d' %
                          (processed_count, len(content)))
            except Exception as e:
                print('Failed to download a study. UID: %s \n exception: %s' %
                      (future_to_study_uid[future], e))



credentials, _ = google.auth.default()
print('Downloading all instances in %s DICOM store' % TRAIN_DICOM_STORE_ID)
download_all_instances(TRAIN_DICOM_STORE_ID, credentials)
print('Downloading all instances in %s DICOM store' % TEST_DICOM_STORE_ID)
download_all_instances(TEST_DICOM_STORE_ID, credentials)
# Out:
# /home/daniil/anaconda3/lib/python3.7/site-packages/google/auth/_default.py:66: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK. We recommend that most server applications use service accounts instead. If your application continues to use end user credentials from Cloud SDK, you might receive a "quota exceeded" or "API not enabled" error. For more information about service accounts, see https://cloud.google.com/docs/authentication/
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# Downloading all instances in dicom-images-train DICOM store
# Processed instance 100 out of 10675
# Processed instance 200 out of 10675
# Processed instance 300 out of 10675
# Processed instance 400 out of 10675
# Processed instance 500 out of 10675
# Processed instance 600 out of 10675
# Processed instance 700 out of 10675
# Processed instance 800 out of 10675
# Processed instance 900 out of 10675
# Processed instance 1000 out of 10675
# Processed instance 1100 out of 10675
# Processed instance 1200 out of 10675
# Processed instance 1300 out of 10675
# Processed instance 1400 out of 10675
# Processed instance 1500 out of 10675
# Processed instance 1600 out of 10675
# Processed instance 1700 out of 10675
# Processed instance 1800 out of 10675
# Processed instance 1900 out of 10675
# Processed instance 2000 out of 10675
# Processed instance 2100 out of 10675
# Processed instance 2200 out of 10675
# Processed instance 2300 out of 10675
# Processed instance 2400 out of 10675
# Processed instance 2500 out of 10675
# Processed instance 2600 out of 10675
# Processed instance 2700 out of 10675
# Processed instance 2800 out of 10675
# Processed instance 2900 out of 10675
# Processed instance 3000 out of 10675
# Processed instance 3100 out of 10675
# Processed instance 3200 out of 10675
# Processed instance 3300 out of 10675
# Processed instance 3400 out of 10675
# Processed instance 3500 out of 10675
# Processed instance 3600 out of 10675
# Processed instance 3700 out of 10675
# Processed instance 3800 out of 10675
# Processed instance 3900 out of 10675
# Processed instance 4000 out of 10675
# Processed instance 4100 out of 10675
# Processed instance 4200 out of 10675
# Processed instance 4300 out of 10675
# Processed instance 4400 out of 10675
# Processed instance 4500 out of 10675
# Processed instance 4600 out of 10675
# Processed instance 4700 out of 10675
# Processed instance 4800 out of 10675
# Processed instance 4900 out of 10675
# Processed instance 5000 out of 10675
# Processed instance 5100 out of 10675
# Processed instance 5200 out of 10675
# Processed instance 5300 out of 10675
# Processed instance 5400 out of 10675
# Processed instance 5500 out of 10675
# Processed instance 5600 out of 10675
# Processed instance 5700 out of 10675
# Processed instance 5800 out of 10675
# Processed instance 5900 out of 10675
# Processed instance 6000 out of 10675
# Processed instance 6100 out of 10675
# Processed instance 6200 out of 10675
# Processed instance 6300 out of 10675
# Processed instance 6400 out of 10675
# Processed instance 6500 out of 10675
# Processed instance 6600 out of 10675
# Processed instance 6700 out of 10675
# Processed instance 6800 out of 10675
# Processed instance 6900 out of 10675
# Processed instance 7000 out of 10675
# Processed instance 7100 out of 10675
# Processed instance 7200 out of 10675
# Processed instance 7300 out of 10675
# Processed instance 7400 out of 10675
# Processed instance 7500 out of 10675
# Processed instance 7600 out of 10675
# Processed instance 7700 out of 10675
# Processed instance 7800 out of 10675
# Processed instance 7900 out of 10675
# Processed instance 8000 out of 10675
# Processed instance 8100 out of 10675
# Processed instance 8200 out of 10675
# Processed instance 8300 out of 10675
# Processed instance 8400 out of 10675
# Processed instance 8500 out of 10675
# Processed instance 8600 out of 10675
# Processed instance 8700 out of 10675
# Processed instance 8800 out of 10675
# Processed instance 8900 out of 10675
# Processed instance 9000 out of 10675
# Processed instance 9100 out of 10675
# Processed instance 9200 out of 10675
# Processed instance 9300 out of 10675
# Processed instance 9400 out of 10675
# Processed instance 9500 out of 10675
# Processed instance 9600 out of 10675
# Processed instance 9700 out of 10675
# Processed instance 9800 out of 10675
# Processed instance 9900 out of 10675
# Processed instance 10000 out of 10675
# Processed instance 10100 out of 10675
# Processed instance 10200 out of 10675
# Processed instance 10300 out of 10675
# Processed instance 10400 out of 10675
# Processed instance 10500 out of 10675
# Processed instance 10600 out of 10675
# Processed instance 10675 out of 10675
# Downloading all instances in dicom-images-test DICOM store
# Processed instance 100 out of 1372
# Processed instance 200 out of 1372
# Processed instance 300 out of 1372
# Processed instance 400 out of 1372
# Processed instance 500 out of 1372
# Processed instance 600 out of 1372
# Processed instance 700 out of 1372
# Processed instance 800 out of 1372
# Processed instance 900 out of 1372
# Processed instance 1000 out of 1372
# Processed instance 1100 out of 1372
# Processed instance 1200 out of 1372
# Processed instance 1300 out of 1372
# Processed instance 1372 out of 1372
