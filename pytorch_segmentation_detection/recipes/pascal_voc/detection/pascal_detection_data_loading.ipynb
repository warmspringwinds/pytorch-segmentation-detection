# %%
# %matplotlib inline

import torchvision
import matplotlib.pyplot as plt

# Coco-like files for pascal for both train and val,
# we should probably reuse them

# .json coco-like annotation file for pascal found in this thread:
# https://github.com/matterport/Mask_RCNN/issues/51
# Direct download link:
# https://storage.googleapis.com/coco-dataset/external/PASCAL_VOC.zip
coco_db = torchvision.datasets.CocoDetection(annFile='/home/daniil/projects/pascal/PASCAL_VOC/pascal_val2012.json',
                                             root='/home/daniil/projects/pascal/dataset/VOCdevkit/VOC2012/JPEGImages/')
# Out:
# loading annotations into memory...
# Done (t=0.22s)
# creating index...
# index created!

# %%
# Getting a randome picture and visualizing the bboxes

img, annotations = coco_db[5]

plt.imshow(img); plt.axis('off')
ax = plt.gca()
coco_db.coco.showAnns(annotations)

# %%
annotations
# Out:
# [{u'area': 181307,
#   u'bbox': [3, 8, 439, 413],
#   u'category_id': 15,
#   u'id': 819,
#   u'ignore': 0,
#   u'image_id': 2008001226,
#   u'iscrowd': 0,
#   u'segmentation': [[3, 8, 3, 421, 442, 421, 442, 8]]},
#  {u'area': 123690,
#   u'bbox': [190, 22, 310, 399],
#   u'category_id': 2,
#   u'id': 820,
#   u'ignore': 0,
#   u'image_id': 2008001226,
#   u'iscrowd': 0,
#   u'segmentation': [[190, 22, 190, 421, 500, 421, 500, 22]]}]
